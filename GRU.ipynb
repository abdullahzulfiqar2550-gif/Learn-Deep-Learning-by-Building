# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=10000)

x_train = tf.keras.preprocessing.sequence.pad_sequences(x_train, maxlen=200)
x_test = tf.keras.preprocessing.sequence.pad_sequences(x_test, maxlen=200)


model = Sequential([
    Embedding(input_dim=10000, output_dim=32),
    GRU(64),
    Dense(1, activation='sigmoid')])


model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])


model.fit(x_train,y_train,epochs=3)


loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - accuracy: 0.7962 - loss: 0.4196
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 34ms/step - accuracy: 0.8991 - loss: 0.2547
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 34ms/step - accuracy: 0.9255 - loss: 0.1967
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8707 - loss: 0.3375
# Test Accuracy: 0.8706799745559692
