# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN

# %%
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test)= mnist.load_data()

# %%
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential()
model.add(SimpleRNN(128, activation='tanh', return_sequences=True))
model.add(SimpleRNN(128, activation='tanh'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
model.fit(
    X_train,
    y_train,
    epochs=3
)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.8916 - loss: 0.3612
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 46s 24ms/step - accuracy: 0.9402 - loss: 0.2079
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 25ms/step - accuracy: 0.9486 - loss: 0.1782

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
mnist = tf.keras.datasets.mnist  
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
x_train = x_train/255
x_test = x_test/255

# %%
model = Sequential()
model.add(LSTM(128, activation='relu', return_sequences=True))
model.add(LSTM(128, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
model.fit(x_train,
          y_train,
          epochs=1)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 105s 56ms/step - accuracy: 0.9816 - loss: 0.0601

# %%
predicted=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step

# %%
predicted[0]
# Out:
# array([7.45779835e-06, 8.12002618e-05, 6.06213289e-04, 6.27621368e-04,
#        2.21684513e-05, 2.68765998e-05, 1.06121796e-07, 9.98284161e-01,
#        4.29555394e-06, 3.39839899e-04], dtype=float32)

# %%
import numpy as np
np.argmax(predicted[0])
y_test[0]
# Out:
# np.uint8(7)

# %%
import matplotlib.pyplot as pt
pt.matshow(x_test[0])

# %%
model.save('modell.keras')
